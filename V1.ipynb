# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyas-13/CV-CS/blob/main/V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Infrared Images

# %%
import cv2
import matplotlib.pyplot as plt
print(cv2.__version__)
# Out:
# 4.6.0

# %% [markdown]
# > Image has been loaded from drive directly if you want to run locally change the path of the image in ***plt.imread()***

# %%
## Loading the image
img = plt.imread('/content/drive/MyDrive/CV-CS/img-1.jpg')
plt.imshow(img)

# %%
## Rotate
img_cpy = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
print('Roatetd Image')
plt.imshow(img_cpy)
# Out:
# Roatetd Image

# %%
## Translation of image
import numpy as np

  
# Store height and width of the image
h, w = img.shape[:2]
  
quarter_h, quarter_w = - h / 4, - w / 4
  
T = np.float32([[1, 0, quarter_w], [0, 1, quarter_h]])
  
# We use warpAffine to transform
# the image using the matrix, T
img_trans = cv2.warpAffine(img, T, (w, h))
  
print('Translated Image')
plt.imshow(img_trans)
# Out:
# Translated Image

# %%
# Scaling the image
scale_percent = 80

h = int(img.shape[0] + (img.shape[0] * scale_percent/100))
w = int(img.shape[1] + (img.shape[1] * scale_percent/100))

new_dim = (h, w)
img_scaled = cv2.resize(img, new_dim, interpolation=cv2.INTER_AREA)

print('Scaled Image')
plt.imshow(img_scaled)

print('Original Image Shape', img.shape[:2])
print('Scaled Image Shape', img_scaled.shape[:2])
# Out:
# Scaled Image
# Original Image Shape (400, 350)
# Scaled Image Shape (630, 720)
